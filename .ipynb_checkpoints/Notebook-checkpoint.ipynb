# %% [markdown]
# # Analyzing model performance
# ### There are many metrics existing for models analization and trying to use the very basic metrics called "Precision-Recall" we see that the model predicted 100% correct, so the score is 1.0 which is ideal.

# %%
from IPython.display import Image
Image(filename='plots/confusion_matrix.png')

# %% [markdown]
# ### Based on the results it seems the model has trained in dataset with data leakage and possibly overfitted

# %% [markdown]
# # Comparing floor and ceiling deviations
# ### The next blocks visualize floor and ceiling mean deviations which may be used for adjusting model behaviour

# %%
from IPython.display import Image
Image(filename='plots/scatter.png')

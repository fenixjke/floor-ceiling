# %% [markdown]
# # Analyzing model performance
# ### There are many metrics exist for models evaluation, however, the confusion matrix shows that the result of the model is 100% correct, so all the metrics will correspond to the perfect model (precision, recall, F1 scores are equal to 1.0).

# %%
from IPython.display import Image
Image(filename='plots/confusion_matrix.png')

# %% [markdown]
# ### Based on the results it seems the model was trained with data leakage or possibly overfitted.

# %% [markdown]
# # Correlation
# ### Heatmap chart shows there is a correlation between some of the features and the target, which means it is possible to build a model with predictive power on this dataset without data leakage and overfitting.

# %%
from IPython.display import Image
Image(filename='plots/correlation.png')

# %% [markdown]
# # Comparing floor and ceiling deviations
# ### Scatter charts allow to visually check how the combination of 2 values relate to the ground truth. The next blocks visualize floor and ceiling mean deviations and indicates some patterns for 4 and 8 corners, which means it makes sense to include both these features into the model.
# ### Also there is only one row where ground truth equals to 10, which means we should exclude this category from the modeling or combine combine 8 and 10 categories into one category depending on the requirements.

# %%
from IPython.display import Image
Image(filename='plots/scatter.png')
